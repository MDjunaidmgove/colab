# %% [markdown]
# <a href="https://colab.research.google.com/github/MDjunaidmgove/colab/blob/main/dataaset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/Iris.csv'
df=pd.read_csv('/content/iris.csv')
df.columns=['sepal_Length','sepal_width','petal_length','petal_width','class']
print(df.columns)
x = df['sepal_Length']
y = df['sepal_width']
plt.scatter(x,y)
plt.xlabel('sepal_length in cm')
plt.ylabel('sepal_width in cm')
plt.title('Scatter Plot')
plt.show()
# Out:
# Index(['sepal_Length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/Iris.csv'
df=pd.read_csv('/content/iris.csv')
df.columns=['sepal_Length','sepal_width','petal_length','petal_width','class']
print(df.columns)
head=df.head(5)
head.plot(kind='bar')
plt.show()
# Out:
# Index(['sepal_Length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/Iris.csv'
df=pd.read_csv('/content/iris.csv')
df.columns=['sepal_Length','sepal_width','petal_length','petal_width','class']
species_count=df['class'].value_counts()
plt.bar(species_count.index,species_count.values,color='red')
plt.xlabel('species')
plt.ylabel('count')
plt.title('bar plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/Iris.csv'
df=pd.read_csv('/content/iris.csv')
df.columns=['sepal_Length','sepal_width','petal_length','petal_width','class']
df.boxplot(column='sepal_Length', by='class')
plt.title('Boxplot of Sepal Length for each Species')
plt.xlabel("Species")
plt.ylabel("Sepal Length")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/mtcars.csv'
df=pd.read_csv('/content/mtcars.csv')
df.columns=['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']
x = df['mpg']
y = df['hp']
plt.scatter(x,y)
plt.xlabel('mpg')
plt.ylabel('hp')
plt.title('Scatter Plot')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/mtcars.csv'
df=pd.read_csv('/content/mtcars.csv')
df.boxplot(column='mpg', by='cyl')
plt.xlabel('Cylinders')
plt.ylabel('MPG')
plt.title('Box Plot of MPG for each Cylinder Count')
plt.suptitle('')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/mtcars.csv'
df=pd.read_csv('/content/mtcars.csv')
plt.bar(df['cyl'], df['mpg'], color='blue')
plt.xlabel('Cyl')
plt.ylabel('MPG')
plt.title('Bar Plot of MPG for Each Car')
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/mtcars.csv'
df=pd.read_csv('/content/mtcars.csv')
plt.hist(df['mpg'], bins=8,color='green',edgecolor='black')
plt.title('Histogram of MPG')
plt.xlabel('MPG')
plt.ylabel("frequency")
plt.grid(True)
plt.show()

# %%
import pandas as pd
car=pd.read_csv('/content/mtcars.csv',names=['car_ID','name','symboling','carname','curbweight','citympg'])
car.head()
# Out:
#                                       car_ID   name symboling carname  \
# model          mpg  cyl disp hp  drat     wt   qsec        vs      am
# Mazda RX4      21   6   160  110 3.9    2.62  16.46         0       1
# Mazda RX4 Wag  21   6   160  110 3.9   2.875  17.02         0       1
# Datsun 710     22.8 4   108  93  3.85   2.32  18.61         1       1
# Hornet 4 Drive 21.4 6   258  110 3.08  3.215  19.44         1       0
#
#                                       curbweight citympg
# model          mpg  cyl disp hp  drat       gear    carb
# Mazda RX4      21   6   160  110 3.9           4       4
# Mazda RX4 Wag  21   6   160  110 3.9           4       4
# Datsun 710     22.8 4   108  93  3.85          4       1
# Hornet 4 Drive 21.4 6   258  110 3.08          3       1

# %% [markdown]
# cie exam
# bar plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/iris.csv'
df=pd.read_csv('/content/Iris.csv')
plt.bar(df['Species'],df['PetalWidthCm'],color='skyblue')
plt.title('bar plot')
plt.xlabel('species')
plt.ylabel('flowers')
plt.grid(True)
plt.show()

# %% [markdown]
# histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/iris.csv'
df=pd.read_csv('/content/Iris.csv')
plt.hist(df['PetalLengthCm'],bins=10,color='skyblue')
plt.title('histogram')
plt.xlabel('length')
plt.ylabel('count')
plt.grid(True)
plt.show()

# %% [markdown]
# boxplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/iris.csv'
df=pd.read_csv('/content/Iris.csv')
df.boxplot(column='PetalLengthCm', by='Species', figsize=(10,6))
plt.title('boxplot')
plt.xlabel('species')
plt.ylabel('length')
plt.grid(True)
plt.show()

# %% [markdown]
# .scatter plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name='/iris.csv'
df=pd.read_csv('/content/Iris.csv')
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'],color='skyblue')
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.title('scatter plot')
plt.show()
